# %% [raw]
# ---
# title: Predict Iris Species
# description: Predict Iris Species with Random Forest
# show-code: False
# output: slides
# format:
#     theme: white
# params:
#     sepal_length:
#         input: numeric
#         label: Sepal Length
#         value: 6.0
#         min: 4.0
#         max: 8.0
#         step: 0.1
#     sepal_width:
#         input: numeric
#         label: Sepal Width
#         value: 3.0
#         min: 2.0
#         max: 4.0
#         step: 0.1
#     petal_length:
#         input: numeric
#         label: Petal Length
#         value: 2.0
#         min: 0.0
#         max: 8.0
#         step: 0.1
#     petal_width:
#         input: numeric
#         label: Peta Width
#         value: 0.5
#         min: 0.0
#         max: 1.0
#         step: 0.1
# ---

# %% [markdown]
# # Predict Iris Species with Random Forest

# %%
sepal_length = 6.0
sepal_width = 3.0
petal_length = 2.0
petal_width = 0.5

# %%
import joblib
import numpy as np
import pandas as pd
from IPython.display import Markdown as md
from sklearn import datasets
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

iris = datasets.load_iris()

# %%
sample = pd.DataFrame({
    'sepal length': [sepal_length],
    'sepal width': [sepal_width],
    'petal length': [petal_length],
    'petal width':  [petal_width],
})

# %% [markdown]
# ## Predict sample class

# %% [markdown]
# Please provide your sample values in the sidebar.

# %%
df = sns.load_dataset('iris')
sns.set(font_scale = 2)
sns.lmplot( x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=True,
           height=8.27, aspect=11.7/8.27)

plt.text(sample["sepal length"][0], sample["sepal width"][0], "Your sample!")
plt.scatter(x=sample["sepal length"][0], y=sample["sepal width"][0], color='#ff0000', linewidth=10)

plt.show()

# %%
df = sns.load_dataset('iris')
sns.set(font_scale = 2)
sns.lmplot( x="petal_length", y="petal_width", data=df, fit_reg=False, hue='species', legend=True,
           height=8.27, aspect=11.7/8.27)

plt.text(sample["petal length"][0], sample["petal width"][0], "Your sample!")
plt.scatter(x=sample["petal length"][0], y=sample["petal width"][0], color='#ff0000', linewidth=10)

plt.show()

# %%
# load Random Forest model from previous notebook

clf = joblib.load("./random_forest.joblib")

# %%
prediction = clf.predict(sample)

# %%
md(f"# Prediction: {iris.target_names[prediction[0]]}")
# Out:
# # Prediction: setosa
